# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_matches=pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Projects/Data Science Revised R_27.07.21/Data Science Projects 14 - IPL Data Analysis/matches.csv')

# %%
df_matches.head()
# Out:
#    id    Season       city  ...         umpire1        umpire2 umpire3
# 0   1  IPL-2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2  IPL-2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3  IPL-2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4  IPL-2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5  IPL-2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
df_matches.shape
# Out:
# (756, 18)

# %%
 df_matches.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
df_matches.Season.unique()
# Out:
# array(['IPL-2017', 'IPL-2008', 'IPL-2009', 'IPL-2010', 'IPL-2011',
#        'IPL-2012', 'IPL-2013', 'IPL-2014', 'IPL-2015', 'IPL-2016',
#        'IPL-2018', 'IPL-2019'], dtype=object)

# %%
#Bar plot of top 5 player of match
pom=df_matches.player_of_match.value_counts().nlargest(5)
plt.figure(figsize=(10,5))
sns.barplot(pom.index,pom)
plt.xlabel('Players Name')
plt.ylabel('Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Count')

# %%
pom
# Out:
# CH Gayle          21
# AB de Villiers    20
# DA Warner         17
# RG Sharma         17
# MS Dhoni          17
# Name: player_of_match, dtype: int64

# %%
#Value counts of results
result_label=df_matches.result.value_counts()
plt.figure(figsize=(10,5))
sns.barplot(result_label.index,result_label)
plt.xlabel('Results')
plt.ylabel('Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Count')

# %%
result_label
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
#Count plot of toss decision
# toss_count=df_matches.toss_decision.value_counts()
plt.figure(figsize=(10,5))
sns.countplot(df_matches.toss_decision)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# toss_count

# %%
#Group by winner
df_matches.groupby('winner')['toss_decision'].value_counts()
# Out:
# winner                       toss_decision
# Chennai Super Kings          bat              52
#                              field            48
# Deccan Chargers              field            15
#                              bat              14
# Delhi Capitals               field             8
#                              bat               2
# Delhi Daredevils             field            38
#                              bat              29
# Gujarat Lions                field            11
#                              bat               2
# Kings XI Punjab              field            61
#                              bat              21
# Kochi Tuskers Kerala         field             6
# Kolkata Knight Riders        field            57
#                              bat              35
# Mumbai Indians               field            64
#                              bat              45
# Pune Warriors                bat               9
#                              field             3
# Rajasthan Royals             field            41
#                              bat              34
# Rising Pune Supergiant       field            10
# Rising Pune Supergiants      field             3
#                              bat               2
# Royal Challengers Bangalore  field            58
#                              bat              26
# Sunrisers Hyderabad          field            37
#                              bat              21
# Name: toss_decision, dtype: int64

# %%
#Barplot of most toss winners
toss_win_label=df_matches.toss_winner.value_counts()
plt.figure(figsize=(10,8))
sns.barplot(toss_win_label,toss_win_label.index)
plt.title('Toss Winners')
plt.xlabel('Counts')
plt.ylabel('Teams')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Teams')

# %%
# teams did fielding first and result was normal
df_matches[(df_matches['toss_decision']=='field') & (df_matches['result']=='normal')].head()
# Out:
#    id    Season       city  ...         umpire1        umpire2 umpire3
# 0   1  IPL-2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2  IPL-2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3  IPL-2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4  IPL-2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 5   6  IPL-2017  Hyderabad  ...      A Deshmukh       NJ Llong     NaN
#
# [5 rows x 18 columns]

# %%
#Team did batting first and won
win=df_matches[(df_matches['toss_decision']=='bat') & (df_matches.win_by_runs!=0)]['winner'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(10,5))
sns.barplot(win,win.index)
plt.xlabel('Count')
plt.ylabel('Teams')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Teams')

# %%
win
# Out:
# Chennai Super Kings            31
# Mumbai Indians                 24
# Kolkata Knight Riders          16
# Rajasthan Royals               14
# Deccan Chargers                11
# Delhi Daredevils               11
# Royal Challengers Bangalore     9
# Sunrisers Hyderabad             8
# Kings XI Punjab                 7
# Pune Warriors                   3
# Delhi Capitals                  1
# Name: winner, dtype: int64

# %%
# Team did bowling first and won
win=df_matches[(df_matches['toss_decision']=='field') & (df_matches.win_by_wickets!=0)]['winner'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(10,5))
sns.barplot(win,win.index)
plt.xlabel('Count')
plt.ylabel('Teams')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Teams')

# %%
win
# Out:
# Kolkata Knight Riders          37
# Mumbai Indians                 31
# Royal Challengers Bangalore    31
# Kings XI Punjab                28
# Chennai Super Kings            27
# Rajasthan Royals               27
# Delhi Daredevils               24
# Sunrisers Hyderabad            15
# Gujarat Lions                  10
# Deccan Chargers                 8
# Delhi Capitals                  5
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         1
# Name: winner, dtype: int64

# %%
# Barplot of won by wickets
plt.figure(figsize=(10,5))
sns.barplot(df_matches.win_by_wickets.value_counts(),df_matches.win_by_wickets.value_counts().index)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Number of matches played each year
season=df_matches.Season.value_counts()
plt.figure(figsize=(10,5))
sns.barplot(season,season.index)
plt.ylabel('IPL Year')
plt.xlabel(' Count of number of matches played')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, ' Count of number of matches played')

# %%
season
# Out:
# IPL-2013    76
# IPL-2012    74
# IPL-2011    73
# IPL-2016    60
# IPL-2018    60
# IPL-2019    60
# IPL-2010    60
# IPL-2014    60
# IPL-2015    59
# IPL-2017    59
# IPL-2008    58
# IPL-2009    57
# Name: Season, dtype: int64

# %%
#Number of matches played in top 10 city
city=df_matches.city.value_counts().sort_values().nlargest(10)
plt.figure(figsize=(10,5))
sns.barplot(city,city.index)
plt.ylabel('city')
plt.xlabel('Count of number of matches played')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Count of number of matches played')

# %%
city
# Out:
# Mumbai        101
# Kolkata        77
# Delhi          74
# Bangalore      66
# Hyderabad      64
# Chennai        57
# Jaipur         47
# Chandigarh     46
# Pune           38
# Durban         15
# Name: city, dtype: int64

# %%
# Anlaysis on deliveries data file
df_deliveries=pd.read_csv('/content/drive/MyDrive/Data Science Project/Data Science Projects/Data Science Revised R_27.07.21/Data Science Projects 14 - IPL Data Analysis/deliveries.csv')

# %%
# Top 5 rows
df_deliveries.head()
# Out:
#    match_id  inning  ... dismissal_kind fielder
# 0         1       1  ...            NaN     NaN
# 1         1       1  ...            NaN     NaN
# 2         1       1  ...            NaN     NaN
# 3         1       1  ...            NaN     NaN
# 4         1       1  ...            NaN     NaN
#
# [5 rows x 21 columns]

# %%
#Shape of data
df_deliveries.shape
# Out:
# (179078, 21)

# %%
#Match Id-1
df_match1=df_deliveries[df_deliveries.match_id==1]
df_match1.head(20)
# Out:
#     match_id  inning  ... dismissal_kind        fielder
# 0          1       1  ...            NaN            NaN
# 1          1       1  ...            NaN            NaN
# 2          1       1  ...            NaN            NaN
# 3          1       1  ...            NaN            NaN
# 4          1       1  ...            NaN            NaN
# 5          1       1  ...            NaN            NaN
# 6          1       1  ...            NaN            NaN
# 7          1       1  ...            NaN            NaN
# 8          1       1  ...            NaN            NaN
# 9          1       1  ...            NaN            NaN
# 10         1       1  ...            NaN            NaN
# 11         1       1  ...         caught  Mandeep Singh
# 12         1       1  ...            NaN            NaN
# 13         1       1  ...            NaN            NaN
# 14         1       1  ...            NaN            NaN
# 15         1       1  ...            NaN            NaN
# 16         1       1  ...            NaN            NaN
# 17         1       1  ...            NaN            NaN
# 18         1       1  ...            NaN            NaN
# 19         1       1  ...            NaN            NaN
#
# [20 rows x 21 columns]

# %%
df_match1.shape
# Out:
# (248, 21)

# %%
df_match1.batting_team.unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore'], dtype=object)

# %%
#1st innings
srh=df_match1[df_match1.inning==1]

# %%
srh.head()
# Out:
#    match_id  inning  ... dismissal_kind fielder
# 0         1       1  ...            NaN     NaN
# 1         1       1  ...            NaN     NaN
# 2         1       1  ...            NaN     NaN
# 3         1       1  ...            NaN     NaN
# 4         1       1  ...            NaN     NaN
#
# [5 rows x 21 columns]

# %%
srh.dismissal_kind.value_counts()
# Out:
# caught    3
# bowled    1
# Name: dismissal_kind, dtype: int64

# %%
#Total numner of balls bowled by SRH
len(srh.ball)
# Out:
# 125

# %%
#Counts of 4s hit by SRH
len(srh[srh.total_runs==4])
# Out:
# 17

# %%
#Counts of 6s hit by SRH
len(srh[srh.total_runs==6])
# Out:
# 9

# %%
#2nd Innings
rcb=df_match1[df_match1.inning==2]

# %%
rcb.head()
# Out:
#      match_id  inning  ... dismissal_kind fielder
# 125         1       2  ...            NaN     NaN
# 126         1       2  ...            NaN     NaN
# 127         1       2  ...            NaN     NaN
# 128         1       2  ...            NaN     NaN
# 129         1       2  ...            NaN     NaN
#
# [5 rows x 21 columns]

# %%
rcb.dismissal_kind.value_counts()
# Out:
# caught     6
# run out    2
# bowled     2
# Name: dismissal_kind, dtype: int64

# %%
#Total number of balls bowled by RCB
len(rcb.ball)
# Out:
# 123

# %%
#Counts of 4s hit by RCB
len(rcb[rcb.total_runs==4])
# Out:
# 15

# %%
#Counts of 6s hit by RCB
len(rcb[rcb.total_runs==6])
# Out:
# 8
